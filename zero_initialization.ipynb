# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("ushape.csv")

# %%
df.head()
# Out:
#           X         Y  class
# 0  2.115098 -0.046244    1.0
# 1  0.882490 -0.075756    0.0
# 2 -0.055144 -0.037332    1.0
# 3  0.829545 -0.539321    1.0
# 4  2.112857  0.662084    1.0

# %%
df.columns=["X", "Y", "class"]
print(df.head())
# Out:
#           X         Y  class
# 0  2.115098 -0.046244    1.0
# 1  0.882490 -0.075756    0.0
# 2 -0.055144 -0.037332    1.0
# 3  0.829545 -0.539321    1.0
# 4  2.112857  0.662084    1.0

# %%
df.to_csv("ushape.csv", index=False)

# %%
plt.scatter(df['X'],df['Y'],c=df['class'])

# %%
X=df.iloc[:,0:2].values
y=df.iloc[:,-1].values

# %%
import tensorflow
from tensorflow import keras
from keras import  Sequential 
from keras.layers import Dense

# %%
model=Sequential()
model.add(Dense(2,activation='relu',input_dim=2))
model.add(Dense(1,activation='sigmoid'))
model.summary()
# Out:
# e:\Deep_Learning\.venv\lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 2)              │             6 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9 (36.00 B)
#  Trainable params: 9 (36.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.get_weights()
# Out:
# [array([[-0.18900287,  1.0577615 ],
#         [-0.20260668, -1.2170457 ]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[ 0.93213356],
#         [-0.46797705]], dtype=float32),
#  array([0.], dtype=float32)]

# %%
initial_weights=model.get_weights()

# %%
initial_weights[0]=np.zeros(model.get_weights()[0].shape)
initial_weights[1]=np.zeros(model.get_weights()[1].shape)
initial_weights[2]=np.zeros(model.get_weights()[2].shape)
initial_weights[3]=np.zeros(model.get_weights()[3].shape)

# %%
model.set_weights(initial_weights)

# %%
model.get_weights()
# Out:
# [array([[0., 0.],
#         [0., 0.]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[0.],
#         [0.]], dtype=float32),
#  array([0.], dtype=float32)]

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
history=model.fit(X,y,epochs=100,validation_split=0.2)
# Out:
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 0.4937 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.4937 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.4937 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 317ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932

# %%
model.get_weights()
# Out:
# [array([[0., 0.],
#         [0., 0.]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[0.],
#         [0.]], dtype=float32),
#  array([0.00715794], dtype=float32)]

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X,y.astype('int'),clf=model,legend=2)
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 24s 3ms/step
# <Axes: >

# %%
# Tahnh will be same as relu coming to the sigmoid

# %%
model=Sequential()
model.add(Dense(2,activation='sigmoid',input_dim=2))
model.add(Dense(1,activation='sigmoid'))
model.summary()
# Out:
# e:\Deep_Learning\.venv\lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 2)              │             6 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9 (36.00 B)
#  Trainable params: 9 (36.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.get_weights()
# Out:
# [array([[ 0.7838937 , -0.94692785],
#         [-0.3067127 ,  0.17616415]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[-0.82913435],
#         [ 0.2428801 ]], dtype=float32),
#  array([0.], dtype=float32)]

# %%
initial_weights=model.get_weights()
initial_weights[0]=np.zeros(model.get_weights()[0].shape)
initial_weights[1]=np.zeros(model.get_weights()[1].shape)
initial_weights[2]=np.zeros(model.get_weights()[2].shape)
initial_weights[3]=np.zeros(model.get_weights()[3].shape)

# %%
model.set_weights(initial_weights)
model.get_weights()
# Out:
# [array([[0., 0.],
#         [0., 0.]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[0.],
#         [0.]], dtype=float32),
#  array([0.], dtype=float32)]

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
history=model.fit(X,y,epochs=100,validation_split=0.2)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.4937 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.4937 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4937 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.4557 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.4937 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.4937 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.4937 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.4937 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.4557 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.4937 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.4937 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4937 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.4937 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.4937 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.4937 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.4937 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.4937 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.4937 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4937 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.4937 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.4937 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.4937 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.4937 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4937 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.4937 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.6456 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6930
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6835 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6930
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5063 - loss: 0.6930 - val_accuracy: 0.5000 - val_loss: 0.6930
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4937 - loss: 0.6930 - val_accuracy: 0.5000 - val_loss: 0.6929
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.4937 - loss: 0.6930 - val_accuracy: 0.5000 - val_loss: 0.6929
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.4937 - loss: 0.6930 - val_accuracy: 0.5000 - val_loss: 0.6929
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.4937 - loss: 0.6929 - val_accuracy: 0.5000 - val_loss: 0.6928
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.4937 - loss: 0.6930 - val_accuracy: 0.5000 - val_loss: 0.6928
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.4937 - loss: 0.6929 - val_accuracy: 0.5000 - val_loss: 0.6927
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.4937 - loss: 0.6929 - val_accuracy: 0.5000 - val_loss: 0.6927
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.4937 - loss: 0.6928 - val_accuracy: 0.5000 - val_loss: 0.6927
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.4937 - loss: 0.6928 - val_accuracy: 0.5000 - val_loss: 0.6926
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.4937 - loss: 0.6928 - val_accuracy: 0.5000 - val_loss: 0.6926
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.4937 - loss: 0.6927 - val_accuracy: 0.5000 - val_loss: 0.6925
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.4937 - loss: 0.6927 - val_accuracy: 0.5000 - val_loss: 0.6924
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.4937 - loss: 0.6926 - val_accuracy: 0.5000 - val_loss: 0.6923
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.4937 - loss: 0.6926 - val_accuracy: 0.5000 - val_loss: 0.6922
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4937 - loss: 0.6925 - val_accuracy: 0.5000 - val_loss: 0.6921
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.4937 - loss: 0.6925 - val_accuracy: 0.5000 - val_loss: 0.6920
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.4937 - loss: 0.6924 - val_accuracy: 0.5000 - val_loss: 0.6919
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.4937 - loss: 0.6923 - val_accuracy: 0.5000 - val_loss: 0.6918
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.4937 - loss: 0.6922 - val_accuracy: 0.5000 - val_loss: 0.6918
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.4937 - loss: 0.6922 - val_accuracy: 0.5000 - val_loss: 0.6916
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.4937 - loss: 0.6921 - val_accuracy: 0.5000 - val_loss: 0.6915
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.4937 - loss: 0.6920 - val_accuracy: 0.5000 - val_loss: 0.6914
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.4937 - loss: 0.6919 - val_accuracy: 0.5000 - val_loss: 0.6913
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.4937 - loss: 0.6919 - val_accuracy: 0.5000 - val_loss: 0.6912
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.4937 - loss: 0.6917 - val_accuracy: 0.5000 - val_loss: 0.6910
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.4937 - loss: 0.6916 - val_accuracy: 0.5000 - val_loss: 0.6909
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.4937 - loss: 0.6915 - val_accuracy: 0.5000 - val_loss: 0.6907
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.4937 - loss: 0.6915 - val_accuracy: 0.5000 - val_loss: 0.6905
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.4937 - loss: 0.6913 - val_accuracy: 0.5000 - val_loss: 0.6904
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.4937 - loss: 0.6912 - val_accuracy: 0.5000 - val_loss: 0.6903
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4937 - loss: 0.6911 - val_accuracy: 0.5000 - val_loss: 0.6901
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.4937 - loss: 0.6910 - val_accuracy: 0.5000 - val_loss: 0.6900
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.4937 - loss: 0.6909 - val_accuracy: 0.5000 - val_loss: 0.6898
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.4937 - loss: 0.6908 - val_accuracy: 0.5000 - val_loss: 0.6897
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.4937 - loss: 0.6907 - val_accuracy: 0.5000 - val_loss: 0.6895
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.4937 - loss: 0.6906 - val_accuracy: 0.5000 - val_loss: 0.6893
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.4937 - loss: 0.6904 - val_accuracy: 0.5000 - val_loss: 0.6891
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.4937 - loss: 0.6903 - val_accuracy: 0.5000 - val_loss: 0.6889
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.4937 - loss: 0.6901 - val_accuracy: 0.5000 - val_loss: 0.6887
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.4937 - loss: 0.6900 - val_accuracy: 0.5000 - val_loss: 0.6885
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.4937 - loss: 0.6898 - val_accuracy: 0.5000 - val_loss: 0.6883
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.4937 - loss: 0.6897 - val_accuracy: 0.5000 - val_loss: 0.6881
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.4937 - loss: 0.6895 - val_accuracy: 0.5000 - val_loss: 0.6878
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.4937 - loss: 0.6893 - val_accuracy: 0.5000 - val_loss: 0.6876
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.4937 - loss: 0.6891 - val_accuracy: 0.5000 - val_loss: 0.6873
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.4937 - loss: 0.6889 - val_accuracy: 0.5000 - val_loss: 0.6871
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.4937 - loss: 0.6887 - val_accuracy: 0.5000 - val_loss: 0.6868
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.4937 - loss: 0.6886 - val_accuracy: 0.5000 - val_loss: 0.6865
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.4937 - loss: 0.6884 - val_accuracy: 0.5000 - val_loss: 0.6863
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.4937 - loss: 0.6882 - val_accuracy: 0.5000 - val_loss: 0.6860
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.4937 - loss: 0.6880 - val_accuracy: 0.5000 - val_loss: 0.6857
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.4937 - loss: 0.6878 - val_accuracy: 0.5000 - val_loss: 0.6854
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.4937 - loss: 0.6875 - val_accuracy: 0.5000 - val_loss: 0.6851
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.4937 - loss: 0.6873 - val_accuracy: 0.5000 - val_loss: 0.6848
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.4937 - loss: 0.6871 - val_accuracy: 0.5000 - val_loss: 0.6844
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.4937 - loss: 0.6868 - val_accuracy: 0.5000 - val_loss: 0.6841
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.4937 - loss: 0.6866 - val_accuracy: 0.5000 - val_loss: 0.6838
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.4937 - loss: 0.6863 - val_accuracy: 0.5000 - val_loss: 0.6834
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.4937 - loss: 0.6861 - val_accuracy: 0.5000 - val_loss: 0.6831
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.4937 - loss: 0.6858 - val_accuracy: 0.5000 - val_loss: 0.6827
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.4937 - loss: 0.6856 - val_accuracy: 0.5000 - val_loss: 0.6823
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.4937 - loss: 0.6853 - val_accuracy: 0.5000 - val_loss: 0.6819
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.4937 - loss: 0.6850 - val_accuracy: 0.5000 - val_loss: 0.6816
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.4937 - loss: 0.6848 - val_accuracy: 0.5000 - val_loss: 0.6812
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.4937 - loss: 0.6845 - val_accuracy: 0.5000 - val_loss: 0.6808
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.4937 - loss: 0.6842 - val_accuracy: 0.5000 - val_loss: 0.6804

# %%
model.get_weights()

# the first input is same and second input is also same
# Out:
# [array([[-0.48878255, -0.48878255],
#         [ 0.52727115,  0.52727115]], dtype=float32),
#  array([-0.03586165, -0.03586165], dtype=float32),
#  array([[-0.1089728],
#         [-0.1089728]], dtype=float32),
#  array([0.0325842], dtype=float32)]

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X,y.astype('int'),clf=model,legend=2)
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step
# <Axes: >
